# %% [markdown]
# <a href="https://colab.research.google.com/github/aryamolmm/thinkpalm-agentai-AryamolMM-ReActAgent/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple ReAct Agent (VERY EASY)

def calculator(exp):
    return str(eval(exp))

def agent(query):
    print("User:", query)

    # THINK
    if any(x in query for x in ["+", "-", "*", "/"]):
        print("Thought: This is a math question")

        # ACT
        expression = query.replace("What is", "").strip().replace("?", "")
        print("Action: Using calculator")
        print("Input:", expression)

        result = calculator(expression)

        # OBSERVE
        print("Observation:", result)

        # FINAL ANSWER
        print("Final Answer:", result)

    else:
        print("Thought: This is general question")
        print("Action: Using search")
        print("Observation: Example search result")
        print("Final Answer: Example result")

# Run it
agent("What is 5 * 10?")
# Out:
# User: What is 5 * 10?
# Thought: This is a math question
# Action: Using calculator
# Input: 5 * 10
# Observation: 50
# Final Answer: 50
